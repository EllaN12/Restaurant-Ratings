# %% [markdown]
# <a href="https://colab.research.google.com/github/EllaN12/Restaurant-Ratings/blob/main/Welcome_To_Colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # New Section

# %%
#import file
#!git clone https://github.com/EllaN12/Restaurant-Ratings.git
# Out:
# Cloning into 'Restaurant-Ratings'...
# remote: Enumerating objects: 45, done.
# remote: Counting objects: 100% (45/45), done.
# remote: Compressing objects: 100% (44/44), done.
# remote: Total 45 (delta 8), reused 0 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (45/45), 388.20 KiB | 3.92 MiB/s, done.
# Resolving deltas: 100% (8/8), done.

# %%
import sys
import os
sys.path.append('/content/Restaurant-Ratings')
os.chdir('/content/Restaurant-Ratings')

# %%
#!pip install -r '/content/Restaurant-Ratings/requirements.txt'
# Out:
# Requirement already satisfied: annotated-types==0.7.0 in /usr/local/lib/python3.11/dist-packages (from -r /content/Restaurant-Ratings/requirements.txt (line 1)) (0.7.0)
# Collecting appnope==0.1.4 (from -r /content/Restaurant-Ratings/requirements.txt (line 2))
#   Downloading appnope-0.1.4-py2.py3-none-any.whl.metadata (908 bytes)
# Collecting asttokens==3.0.0 (from -r /content/Restaurant-Ratings/requirements.txt (line 3))
#   Downloading asttokens-3.0.0-py3-none-any.whl.metadata (4.7 kB)
# Requirement already satisfied: attrs==25.1.0 in /usr/local/lib/python3.11/dist-packages (from -r /content/Restaurant-Ratings/requirements.txt (line 4)) (25.1.0)
# Requirement already satisfied: backcall==0.2.0 in /usr/local/lib/python3.11/dist-packages (from -r /content/Restaurant-Ratings/requirements.txt (line 5)) (0.2.0)
# Requirement already satisfied: beautifulsoup4==4.13.3 in /usr/local/lib/python3.11/dist-packages (from -r /content/Restaurant-Ratings/requirements.txt (line 6)) (4.13.3)
# Requirement already satisfied: bleach==6.2.0 in /usr/local/lib/python3.11/dist-packages (from -r /content/Restaurant-Ratings/requirements.txt (line 7)) (6.2.0)
# Requirement already satisfied: causal-learn==0.1.4.0 in /usr/local/lib/python3.11/dist-packages (from -r /content/Restaurant-Ratings/requirements.txt (line 8)) (0.1.4.0)
# Collecting causalgraphicalmodels==0.0.4 (from -r /content/Restaurant-Ratings/requirements.txt (line 9))
#   Downloading causalgraphicalmodels-0.0.4-py3-none-any.whl.metadata (2.3 kB)
# Requirement already satisfied: certifi==2025.1.31 in /usr/local/lib/python3.11/dist-packages (from -r /content/Restaurant-Ratings/requirements.txt (line 10)) (2025.1.31)
# Requirement already satisfied: charset-normalizer==3.4.1 in /usr/local/lib/python3.11/dist-packages (from -r /content/Restaurant-Ratings/requirements.txt (line 11)) (3.4.1)
# Requirement already satisfied: clarabel==0.10.0 in /usr/local/lib/python3.11/dist-packages (from -r /content/Restaurant-Ratings/requirements.txt (line 12)) (0.10.0)
# Collecting comm==0.2.2 (from -r /content/Restaurant-Ratings/requirements.txt (line 13))
#   Downloading comm-0.2.2-py3-none-any.whl.metadata (3.7 kB)
# Requirement already satisfied: contourpy==1.3.1 in /usr/local/lib/python3.11/dist-packages (from -r /content/Restaurant-Ratings/requirements.txt (line 14)) (1.3.1)
# Collecting cvxpy==1.6.1 (from -r /content/Restaurant-Ratings/requirements.txt (line 15))
#   Downloading cvxpy-1.6.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (9.3 kB)
# Requirement already satisfied: cycler==0.12.1 in /usr/local/lib/python3.11/dist-packages (from -r /content/Restaurant-Ratings/requirements.txt (line 16)) (0.12.1)
# Requirement already satisfied: Cython==0.29.37 in /usr/local/lib/python3.11/dist-packages (from -r /content/Restaurant-Ratings/requirements.txt (line 17)) (0.29.37)
# Collecting dacite==1.9.2 (from -r /content/Restaurant-Ratings/requirements.txt (line 18))
#   Downloading dacite-1.9.2-py3-none-any.whl.metadata (17 kB)
# Collecting debugpy==1.8.12 (from -r /content/Restaurant-Ratings/requirements.txt (line 19))
#   Downloading debugpy-1.8.12-cp311-cp311-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (1.3 kB)
# Collecting decorator==5.2.1 (from -r /content/Restaurant-Ratings/requirements.txt (line 20))
#   Downloading decorator-5.2.1-py3-none-any.whl.metadata (3.9 kB)
# Requirement already satisfied: defusedxml==0.7.1 in /usr/local/lib/python3.11/dist-packages (from -r /content/Restaurant-Ratings/requirements.txt (line 21)) (0.7.1)
# Collecting docopt==0.6.2 (from -r /content/Restaurant-Ratings/requirements.txt (line 22))
#   Downloading docopt-0.6.2.tar.gz (25 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: dowhy==0.12 in /usr/local/lib/python3.11/dist-packages (from -r /content/Restaurant-Ratings/requirements.txt (line 23)) (0.12)
# Collecting executing==2.2.0 (from -r /content/Restaurant-Ratings/requirements.txt (line 24))
#   Downloading executing-2.2.0-py2.py3-none-any.whl.metadata (8.9 kB)
# Requirement already satisfied: fastjsonschema==2.21.1 in /usr/local/lib/python3.11/dist-packages (from -r /content/Restaurant-Ratings/requirements.txt (line 25)) (2.21.1)
# Requirement already satisfied: fonttools==4.56.0 in /usr/local/lib/python3.11/dist-packages (from -r /content/Restaurant-Ratings/requirements.txt (line 26)) (4.56.0)
# Requirement already satisfied: geographiclib==2.0 in /usr/local/lib/python3.11/dist-packages (from -r /content/Restaurant-Ratings/requirements.txt (line 27)) (2.0)
# Requirement already satisfied: geopy==2.4.1 in /usr/local/lib/python3.11/dist-packages (from -r /content/Restaurant-Ratings/requirements.txt (line 28)) (2.4.1)
# Requirement already satisfied: graphviz==0.20.3 in /usr/local/lib/python3.11/dist-packages (from -r /content/Restaurant-Ratings/requirements.txt (line 29)) (0.20.3)
# Requirement already satisfied: h11==0.14.0 in /usr/local/lib/python3.11/dist-packages (from -r /content/Restaurant-Ratings/requirements.txt (line 30)) (0.14.0)
# Collecting htmlmin==0.1.12 (from -r /content/Restaurant-Ratings/requirements.txt (line 31))
#   Downloading htmlmin-0.1.12.tar.gz (19 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: idna==3.10 in /usr/local/lib/python3.11/dist-packages (from -r /content/Restaurant-Ratings/requirements.txt (line 32)) (3.10)
# Collecting ImageHash==4.3.1 (from -r /content/Restaurant-Ratings/requirements.txt (line 33))
#   Downloading ImageHash-4.3.1-py2.py3-none-any.whl.metadata (8.0 kB)
# Collecting ipykernel==6.29.5 (from -r /content/Restaurant-Ratings/requirements.txt (line 34))
#   Downloading ipykernel-6.29.5-py3-none-any.whl.metadata (6.3 kB)
# Collecting ipython==8.12.3 (from -r /content/Restaurant-Ratings/requirements.txt (line 35))
#   Downloading ipython-8.12.3-py3-none-any.whl.metadata (5.7 kB)
# Collecting jedi==0.19.2 (from -r /content/Restaurant-Ratings/requirements.txt (line 36))
#   Downloading jedi-0.19.2-py2.py3-none-any.whl.metadata (22 kB)
# Requirement already satisfied: Jinja2==3.1.5 in /usr/local/lib/python3.11/dist-packages (from -r /content/Restaurant-Ratings/requirements.txt (line 37)) (3.1.5)
# Requirement already satisfied: joblib==1.4.2 in /usr/local/lib/python3.11/dist-packages (from -r /content/Restaurant-Ratings/requirements.txt (line 38)) (1.4.2)
# Requirement already satisfied: jsonschema==4.23.0 in /usr/local/lib/python3.11/dist-packages (from -r /content/Restaurant-Ratings/requirements.txt (line 39)) (4.23.0)
# Requirement already satisfied: jsonschema-specifications==2024.10.1 in /usr/local/lib/python3.11/dist-packages (from -r /content/Restaurant-Ratings/requirements.txt (line 40)) (2024.10.1)
# Collecting jupyter_client==8.6.3 (from -r /content/Restaurant-Ratings/requirements.txt (line 41))
#   Downloading jupyter_client-8.6.3-py3-none-any.whl.metadata (8.3 kB)
# Requirement already satisfied: jupyter_core==5.7.2 in /usr/local/lib/python3.11/dist-packages (from -r /content/Restaurant-Ratings/requirements.txt (line 42)) (5.7.2)
# Requirement already satisfied: jupyterlab_pygments==0.3.0 in /usr/local/lib/python3.11/dist-packages (from -r /content/Restaurant-Ratings/requirements.txt (line 43)) (0.3.0)
# Requirement already satisfied: kiwisolver==1.4.8 in /usr/local/lib/python3.11/dist-packages (from -r /content/Restaurant-Ratings/requirements.txt (line 44)) (1.4.8)
# Requirement already satisfied: llvmlite==0.44.0 in /usr/local/lib/python3.11/dist-packages (from -r /content/Restaurant-Ratings/requirements.txt (line 45)) (0.44.0)
# Requirement already satisfied: MarkupSafe==3.0.2 in /usr/local/lib/python3.11/dist-packages (from -r /content/Restaurant-Ratings/requirements.txt (line 46)) (3.0.2)
# Requirement already satisfied: matplotlib==3.10.0 in /usr/local/lib/python3.11/dist-packages (from -r /content/Restaurant-Ratings/requirements.txt (line 47)) (3.10.0)
# Requirement already satisfied: matplotlib-inline==0.1.7 in /usr/local/lib/python3.11/dist-packages (from -r /content/Restaurant-Ratings/requirements.txt (line 48)) (0.1.7)
# Requirement already satisfied: mistune==3.1.2 in /usr/local/lib/python3.11/dist-packages (from -r /content/Restaurant-Ratings/requirements.txt (line 49)) (3.1.2)
# Requirement already satisfied: momentchi2==0.1.8 in /usr/local/lib/python3.11/dist-packages (from -r /content/Restaurant-Ratings/requirements.txt (line 50)) (0.1.8)
# Requirement already satisfied: mpmath==1.3.0 in /usr/local/lib/python3.11/dist-packages (from -r /content/Restaurant-Ratings/requirements.txt (line 51)) (1.3.0)
# Collecting multimethod==1.12 (from -r /content/Restaurant-Ratings/requirements.txt (line 52))
#   Downloading multimethod-1.12-py3-none-any.whl.metadata (9.6 kB)
# Requirement already satisfied: nbclient==0.10.2 in /usr/local/lib/python3.11/dist-packages (from -r /content/Restaurant-Ratings/requirements.txt (line 53)) (0.10.2)
# Requirement already satisfied: nbconvert==7.16.6 in /usr/local/lib/python3.11/dist-packages (from -r /content/Restaurant-Ratings/requirements.txt (line 54)) (7.16.6)
# Requirement already satisfied: nbformat==5.10.4 in /usr/local/lib/python3.11/dist-packages (from -r /content/Restaurant-Ratings/requirements.txt (line 55)) (5.10.4)
# Requirement already satisfied: nest-asyncio==1.6.0 in /usr/local/lib/python3.11/dist-packages (from -r /content/Restaurant-Ratings/requirements.txt (line 56)) (1.6.0)
# Requirement already satisfied: networkx==3.4.2 in /usr/local/lib/python3.11/dist-packages (from -r /content/Restaurant-Ratings/requirements.txt (line 57)) (3.4.2)
# Requirement already satisfied: numba==0.61.0 in /usr/local/lib/python3.11/dist-packages (from -r /content/Restaurant-Ratings/requirements.txt (line 58)) (0.61.0)
# Collecting numpy==2.1.3 (from -r /content/Restaurant-Ratings/requirements.txt (line 59))
#   Downloading numpy-2.1.3-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (62 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.0/62.0 kB 2.5 MB/s eta 0:00:00
# Requirement already satisfied: osqp==0.6.7.post3 in /usr/local/lib/python3.11/dist-packages (from -r /content/Restaurant-Ratings/requirements.txt (line 60)) (0.6.7.post3)
# Collecting outcome==1.3.0.post0 (from -r /content/Restaurant-Ratings/requirements.txt (line 61))
#   Downloading outcome-1.3.0.post0-py2.py3-none-any.whl.metadata (2.6 kB)
# Requirement already satisfied: packaging==24.2 in /usr/local/lib/python3.11/dist-packages (from -r /content/Restaurant-Ratings/requirements.txt (line 62)) (24.2)
# Collecting pandas==2.2.3 (from -r /content/Restaurant-Ratings/requirements.txt (line 63))
#   Downloading pandas-2.2.3-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (89 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 89.9/89.9 kB 6.5 MB/s eta 0:00:00
# Collecting pandas-flavor==0.6.0 (from -r /content/Restaurant-Ratings/requirements.txt (line 64))
#   Downloading pandas_flavor-0.6.0-py3-none-any.whl.metadata (6.3 kB)
# Requirement already satisfied: pandocfilters==1.5.1 in /usr/local/lib/python3.11/dist-packages (from -r /content/Restaurant-Ratings/requirements.txt (line 65)) (1.5.1)
# Requirement already satisfied: parso==0.8.4 in /usr/local/lib/python3.11/dist-packages (from -r /content/Restaurant-Ratings/requirements.txt (line 66)) (0.8.4)
# Requirement already satisfied: patsy==1.0.1 in /usr/local/lib/python3.11/dist-packages (from -r /content/Restaurant-Ratings/requirements.txt (line 67)) (1.0.1)
# Requirement already satisfied: pexpect==4.9.0 in /usr/local/lib/python3.11/dist-packages (from -r /content/Restaurant-Ratings/requirements.txt (line 68)) (4.9.0)
# Collecting phik==0.12.4 (from -r /content/Restaurant-Ratings/requirements.txt (line 69))
#   Downloading phik-0.12.4-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (5.6 kB)
# Requirement already satisfied: pickleshare==0.7.5 in /usr/local/lib/python3.11/dist-packages (from -r /content/Restaurant-Ratings/requirements.txt (line 70)) (0.7.5)
# Requirement already satisfied: pillow==11.1.0 in /usr/local/lib/python3.11/dist-packages (from -r /content/Restaurant-Ratings/requirements.txt (line 71)) (11.1.0)
# Collecting pipreqs==0.5.0 (from -r /content/Restaurant-Ratings/requirements.txt (line 72))
#   Downloading pipreqs-0.5.0-py3-none-any.whl.metadata (7.9 kB)
# Requirement already satisfied: platformdirs==4.3.6 in /usr/local/lib/python3.11/dist-packages (from -r /content/Restaurant-Ratings/requirements.txt (line 73)) (4.3.6)
# Requirement already satisfied: prompt_toolkit==3.0.50 in /usr/local/lib/python3.11/dist-packages (from -r /content/Restaurant-Ratings/requirements.txt (line 74)) (3.0.50)
# Collecting psutil==7.0.0 (from -r /content/Restaurant-Ratings/requirements.txt (line 75))
#   Downloading psutil-7.0.0-cp36-abi3-manylinux_2_12_x86_64.manylinux2010_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (22 kB)
# Requirement already satisfied: ptyprocess==0.7.0 in /usr/local/lib/python3.11/dist-packages (from -r /content/Restaurant-Ratings/requirements.txt (line 76)) (0.7.0)
# Collecting pure_eval==0.2.3 (from -r /content/Restaurant-Ratings/requirements.txt (line 77))
#   Downloading pure_eval-0.2.3-py3-none-any.whl.metadata (6.3 kB)
# Requirement already satisfied: pydantic==2.10.6 in /usr/local/lib/python3.11/dist-packages (from -r /content/Restaurant-Ratings/requirements.txt (line 78)) (2.10.6)
# Requirement already satisfied: pydantic_core==2.27.2 in /usr/local/lib/python3.11/dist-packages (from -r /content/Restaurant-Ratings/requirements.txt (line 79)) (2.27.2)
# Requirement already satisfied: pydot==3.0.4 in /usr/local/lib/python3.11/dist-packages (from -r /content/Restaurant-Ratings/requirements.txt (line 80)) (3.0.4)
# Collecting Pygments==2.19.1 (from -r /content/Restaurant-Ratings/requirements.txt (line 81))
#   Downloading pygments-2.19.1-py3-none-any.whl.metadata (2.5 kB)
# Requirement already satisfied: pyparsing==3.2.1 in /usr/local/lib/python3.11/dist-packages (from -r /content/Restaurant-Ratings/requirements.txt (line 82)) (3.2.1)
# Requirement already satisfied: PySocks==1.7.1 in /usr/local/lib/python3.11/dist-packages (from -r /content/Restaurant-Ratings/requirements.txt (line 83)) (1.7.1)
# Collecting python-dateutil==2.9.0.post0 (from -r /content/Restaurant-Ratings/requirements.txt (line 84))
#   Downloading python_dateutil-2.9.0.post0-py2.py3-none-any.whl.metadata (8.4 kB)
# Collecting python-dotenv==1.0.1 (from -r /content/Restaurant-Ratings/requirements.txt (line 85))
#   Downloading python_dotenv-1.0.1-py3-none-any.whl.metadata (23 kB)
# Requirement already satisfied: pytz==2025.1 in /usr/local/lib/python3.11/dist-packages (from -r /content/Restaurant-Ratings/requirements.txt (line 86)) (2025.1)
# Collecting PyWavelets==1.8.0 (from -r /content/Restaurant-Ratings/requirements.txt (line 87))
#   Downloading pywavelets-1.8.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (9.0 kB)
# Requirement already satisfied: PyYAML==6.0.2 in /usr/local/lib/python3.11/dist-packages (from -r /content/Restaurant-Ratings/requirements.txt (line 88)) (6.0.2)
# Collecting pyzmq==26.2.1 (from -r /content/Restaurant-Ratings/requirements.txt (line 89))
#   Downloading pyzmq-26.2.1-cp311-cp311-manylinux_2_28_x86_64.whl.metadata (6.2 kB)
# Requirement already satisfied: qdldl==0.1.7.post5 in /usr/local/lib/python3.11/dist-packages (from -r /content/Restaurant-Ratings/requirements.txt (line 90)) (0.1.7.post5)
# Requirement already satisfied: referencing==0.36.2 in /usr/local/lib/python3.11/dist-packages (from -r /content/Restaurant-Ratings/requirements.txt (line 91)) (0.36.2)
# Requirement already satisfied: requests==2.32.3 in /usr/local/lib/python3.11/dist-packages (from -r /content/Restaurant-Ratings/requirements.txt (line 92)) (2.32.3)
# Requirement already satisfied: rpds-py==0.23.1 in /usr/local/lib/python3.11/dist-packages (from -r /content/Restaurant-Ratings/requirements.txt (line 93)) (0.23.1)
# Requirement already satisfied: scikit-learn==1.6.1 in /usr/local/lib/python3.11/dist-packages (from -r /content/Restaurant-Ratings/requirements.txt (line 94)) (1.6.1)
# Collecting scipy==1.15.2 (from -r /content/Restaurant-Ratings/requirements.txt (line 95))
#   Downloading scipy-1.15.2-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (61 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.0/62.0 kB 4.0 MB/s eta 0:00:00
# Requirement already satisfied: scs==3.2.7.post2 in /usr/local/lib/python3.11/dist-packages (from -r /content/Restaurant-Ratings/requirements.txt (line 96)) (3.2.7.post2)
# Requirement already satisfied: seaborn==0.13.2 in /usr/local/lib/python3.11/dist-packages (from -r /content/Restaurant-Ratings/requirements.txt (line 97)) (0.13.2)
# Collecting selenium==4.29.0 (from -r /content/Restaurant-Ratings/requirements.txt (line 98))
#   Downloading selenium-4.29.0-py3-none-any.whl.metadata (7.1 kB)
# Collecting setuptools==75.8.1 (from -r /content/Restaurant-Ratings/requirements.txt (line 99))
#   Downloading setuptools-75.8.1-py3-none-any.whl.metadata (6.7 kB)
# Requirement already satisfied: six==1.17.0 in /usr/local/lib/python3.11/dist-packages (from -r /content/Restaurant-Ratings/requirements.txt (line 100)) (1.17.0)
# Requirement already satisfied: sniffio==1.3.1 in /usr/local/lib/python3.11/dist-packages (from -r /content/Restaurant-Ratings/requirements.txt (line 101)) (1.3.1)
# Requirement already satisfied: sortedcontainers==2.4.0 in /usr/local/lib/python3.11/dist-packages (from -r /content/Restaurant-Ratings/requirements.txt (line 102)) (2.4.0)
# Requirement already satisfied: soupsieve==2.6 in /usr/local/lib/python3.11/dist-packages (from -r /content/Restaurant-Ratings/requirements.txt (line 103)) (2.6)
# Collecting stack-data==0.6.3 (from -r /content/Restaurant-Ratings/requirements.txt (line 104))
#   Downloading stack_data-0.6.3-py3-none-any.whl.metadata (18 kB)
# Requirement already satisfied: statsmodels==0.14.4 in /usr/local/lib/python3.11/dist-packages (from -r /content/Restaurant-Ratings/requirements.txt (line 105)) (0.14.4)
# Collecting sympy==1.13.3 (from -r /content/Restaurant-Ratings/requirements.txt (line 106))
#   Downloading sympy-1.13.3-py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: threadpoolctl==3.5.0 in /usr/local/lib/python3.11/dist-packages (from -r /content/Restaurant-Ratings/requirements.txt (line 107)) (3.5.0)
# Requirement already satisfied: tinycss2==1.4.0 in /usr/local/lib/python3.11/dist-packages (from -r /content/Restaurant-Ratings/requirements.txt (line 108)) (1.4.0)
# Requirement already satisfied: tornado==6.4.2 in /usr/local/lib/python3.11/dist-packages (from -r /content/Restaurant-Ratings/requirements.txt (line 109)) (6.4.2)
# Requirement already satisfied: tqdm==4.67.1 in /usr/local/lib/python3.11/dist-packages (from -r /content/Restaurant-Ratings/requirements.txt (line 110)) (4.67.1)
# Collecting traitlets==5.14.3 (from -r /content/Restaurant-Ratings/requirements.txt (line 111))
#   Downloading traitlets-5.14.3-py3-none-any.whl.metadata (10 kB)
# Collecting trio==0.29.0 (from -r /content/Restaurant-Ratings/requirements.txt (line 112))
#   Downloading trio-0.29.0-py3-none-any.whl.metadata (8.5 kB)
# Collecting trio-websocket==0.12.2 (from -r /content/Restaurant-Ratings/requirements.txt (line 113))
#   Downloading trio_websocket-0.12.2-py3-none-any.whl.metadata (5.1 kB)
# Requirement already satisfied: typeguard==4.4.2 in /usr/local/lib/python3.11/dist-packages (from -r /content/Restaurant-Ratings/requirements.txt (line 114)) (4.4.2)
# Requirement already satisfied: typing_extensions==4.12.2 in /usr/local/lib/python3.11/dist-packages (from -r /content/Restaurant-Ratings/requirements.txt (line 115)) (4.12.2)
# Requirement already satisfied: tzdata==2025.1 in /usr/local/lib/python3.11/dist-packages (from -r /content/Restaurant-Ratings/requirements.txt (line 116)) (2025.1)
# Requirement already satisfied: urllib3==2.3.0 in /usr/local/lib/python3.11/dist-packages (from -r /content/Restaurant-Ratings/requirements.txt (line 117)) (2.3.0)
# Collecting visions==0.7.6 (from -r /content/Restaurant-Ratings/requirements.txt (line 118))
#   Downloading visions-0.7.6-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: wcwidth==0.2.13 in /usr/local/lib/python3.11/dist-packages (from -r /content/Restaurant-Ratings/requirements.txt (line 119)) (0.2.13)
# Collecting webdriver-manager==4.0.2 (from -r /content/Restaurant-Ratings/requirements.txt (line 120))
#   Downloading webdriver_manager-4.0.2-py2.py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: webencodings==0.5.1 in /usr/local/lib/python3.11/dist-packages (from -r /content/Restaurant-Ratings/requirements.txt (line 121)) (0.5.1)
# Requirement already satisfied: websocket-client==1.8.0 in /usr/local/lib/python3.11/dist-packages (from -r /content/Restaurant-Ratings/requirements.txt (line 122)) (1.8.0)
# Requirement already satisfied: wordcloud==1.9.4 in /usr/local/lib/python3.11/dist-packages (from -r /content/Restaurant-Ratings/requirements.txt (line 123)) (1.9.4)
# Collecting wsproto==1.2.0 (from -r /content/Restaurant-Ratings/requirements.txt (line 124))
#   Downloading wsproto-1.2.0-py3-none-any.whl.metadata (5.6 kB)
# Requirement already satisfied: xarray==2025.1.2 in /usr/local/lib/python3.11/dist-packages (from -r /content/Restaurant-Ratings/requirements.txt (line 125)) (2025.1.2)
# Collecting yarg==0.1.9 (from -r /content/Restaurant-Ratings/requirements.txt (line 126))
#   Downloading yarg-0.1.9-py2.py3-none-any.whl.metadata (4.6 kB)
# Collecting ydata-profiling==4.12.2 (from -r /content/Restaurant-Ratings/requirements.txt (line 127))
#   Downloading ydata_profiling-4.12.2-py2.py3-none-any.whl.metadata (20 kB)
# Downloading appnope-0.1.4-py2.py3-none-any.whl (4.3 kB)
# Downloading asttokens-3.0.0-py3-none-any.whl (26 kB)
# Downloading causalgraphicalmodels-0.0.4-py3-none-any.whl (11 kB)
# Downloading comm-0.2.2-py3-none-any.whl (7.2 kB)
# Downloading cvxpy-1.6.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 23.0 MB/s eta 0:00:00
# Downloading dacite-1.9.2-py3-none-any.whl (16 kB)
# Downloading debugpy-1.8.12-cp311-cp311-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 53.2 MB/s eta 0:00:00
# Downloading decorator-5.2.1-py3-none-any.whl (9.2 kB)
# Downloading executing-2.2.0-py2.py3-none-any.whl (26 kB)
# Downloading ImageHash-4.3.1-py2.py3-none-any.whl (296 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 296.5/296.5 kB 17.9 MB/s eta 0:00:00
# Downloading ipykernel-6.29.5-py3-none-any.whl (117 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 117.2/117.2 kB 7.9 MB/s eta 0:00:00
# Downloading ipython-8.12.3-py3-none-any.whl (798 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 798.3/798.3 kB 32.8 MB/s eta 0:00:00
# Downloading jedi-0.19.2-py2.py3-none-any.whl (1.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 43.9 MB/s eta 0:00:00
# Downloading jupyter_client-8.6.3-py3-none-any.whl (106 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 106.1/106.1 kB 6.6 MB/s eta 0:00:00
# Downloading multimethod-1.12-py3-none-any.whl (10 kB)
# Downloading numpy-2.1.3-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (16.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.3/16.3 MB 53.0 MB/s eta 0:00:00
# Downloading outcome-1.3.0.post0-py2.py3-none-any.whl (10 kB)
# Downloading pandas-2.2.3-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (13.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.1/13.1 MB 69.2 MB/s eta 0:00:00
# Downloading pandas_flavor-0.6.0-py3-none-any.whl (7.2 kB)
# Downloading phik-0.12.4-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (687 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 687.8/687.8 kB 34.4 MB/s eta 0:00:00
# Downloading pipreqs-0.5.0-py3-none-any.whl (33 kB)
# Downloading psutil-7.0.0-cp36-abi3-manylinux_2_12_x86_64.manylinux2010_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (277 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 278.0/278.0 kB 19.4 MB/s eta 0:00:00
# Downloading pure_eval-0.2.3-py3-none-any.whl (11 kB)
# Downloading pygments-2.19.1-py3-none-any.whl (1.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 50.1 MB/s eta 0:00:00
# Downloading python_dateutil-2.9.0.post0-py2.py3-none-any.whl (229 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 229.9/229.9 kB 16.5 MB/s eta 0:00:00
# Downloading python_dotenv-1.0.1-py3-none-any.whl (19 kB)
# Downloading pywavelets-1.8.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (4.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.5/4.5 MB 78.7 MB/s eta 0:00:00
# Downloading pyzmq-26.2.1-cp311-cp311-manylinux_2_28_x86_64.whl (874 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 874.5/874.5 kB 40.6 MB/s eta 0:00:00
# Downloading scipy-1.15.2-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (37.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 37.6/37.6 MB 13.3 MB/s eta 0:00:00
# Downloading selenium-4.29.0-py3-none-any.whl (9.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.5/9.5 MB 55.8 MB/s eta 0:00:00
# Downloading setuptools-75.8.1-py3-none-any.whl (1.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 43.4 MB/s eta 0:00:00
# Downloading stack_data-0.6.3-py3-none-any.whl (24 kB)
# Downloading sympy-1.13.3-py3-none-any.whl (6.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.2/6.2 MB 63.3 MB/s eta 0:00:00
# Downloading traitlets-5.14.3-py3-none-any.whl (85 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 85.4/85.4 kB 6.5 MB/s eta 0:00:00
# Downloading trio-0.29.0-py3-none-any.whl (492 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 492.9/492.9 kB 21.7 MB/s eta 0:00:00
# Downloading trio_websocket-0.12.2-py3-none-any.whl (21 kB)
# Downloading visions-0.7.6-py3-none-any.whl (104 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 104.8/104.8 kB 6.7 MB/s eta 0:00:00
# Downloading webdriver_manager-4.0.2-py2.py3-none-any.whl (27 kB)
# Downloading wsproto-1.2.0-py3-none-any.whl (24 kB)
# Downloading yarg-0.1.9-py2.py3-none-any.whl (19 kB)
# Downloading ydata_profiling-4.12.2-py2.py3-none-any.whl (390 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 390.9/390.9 kB 22.0 MB/s eta 0:00:00
# Building wheels for collected packages: docopt, htmlmin
#   Building wheel for docopt (setup.py) ... done
#   Created wheel for docopt: filename=docopt-0.6.2-py2.py3-none-any.whl size=13706 sha256=e46550b312e4cb7f581e428dc76d468e59bf4920f208d5aca14d969f3457f070
#   Stored in directory: /root/.cache/pip/wheels/1a/b0/8c/4b75c4116c31f83c8f9f047231251e13cc74481cca4a78a9ce
#   Building wheel for htmlmin (setup.py) ... done
#   Created wheel for htmlmin: filename=htmlmin-0.1.12-py3-none-any.whl size=27081 sha256=649a6ed226fdf609930fee449fd27c3d1bd2b340e924581e460fcd525fcd89cc
#   Stored in directory: /root/.cache/pip/wheels/8d/55/1a/19cd535375ed1ede0c996405ebffe34b196d78e2d9545723a2
# Successfully built docopt htmlmin
# Installing collected packages: pure_eval, htmlmin, docopt, wsproto, traitlets, sympy, setuptools, pyzmq, python-dotenv, python-dateutil, Pygments, psutil, outcome, numpy, multimethod, jedi, executing, decorator, debugpy, dacite, asttokens, appnope, yarg, webdriver-manager, trio, stack-data, scipy, PyWavelets, pandas, comm, visions, trio-websocket, jupyter_client, ipython, ImageHash, causalgraphicalmodels, selenium, phik, pandas-flavor, ipykernel, ydata-profiling, cvxpy, pipreqs
#   Attempting uninstall: traitlets
#     Found existing installation: traitlets 5.7.1
#     Uninstalling traitlets-5.7.1:
#       Successfully uninstalled traitlets-5.7.1
#   Attempting uninstall: sympy
#     Found existing installation: sympy 1.13.1
#     Uninstalling sympy-1.13.1:
#       Successfully uninstalled sympy-1.13.1
#   Attempting uninstall: setuptools
#     Found existing installation: setuptools 75.1.0
#     Uninstalling setuptools-75.1.0:
#       Successfully uninstalled setuptools-75.1.0
#   Attempting uninstall: pyzmq
#     Found existing installation: pyzmq 24.0.1
#     Uninstalling pyzmq-24.0.1:
#       Successfully uninstalled pyzmq-24.0.1
#   Attempting uninstall: python-dateutil
#     Found existing installation: python-dateutil 2.8.2
#     Uninstalling python-dateutil-2.8.2:
#       Successfully uninstalled python-dateutil-2.8.2
#   Attempting uninstall: Pygments
#     Found existing installation: Pygments 2.18.0
#     Uninstalling Pygments-2.18.0:
#       Successfully uninstalled Pygments-2.18.0
#   Attempting uninstall: psutil
#     Found existing installation: psutil 5.9.5
#     Uninstalling psutil-5.9.5:
#       Successfully uninstalled psutil-5.9.5
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.26.4
#     Uninstalling numpy-1.26.4:
#       Successfully uninstalled numpy-1.26.4
#   Attempting uninstall: decorator
#     Found existing installation: decorator 4.4.2
#     Uninstalling decorator-4.4.2:
#       Successfully uninstalled decorator-4.4.2
#   Attempting uninstall: debugpy
#     Found existing installation: debugpy 1.8.0
#     Uninstalling debugpy-1.8.0:
#       Successfully uninstalled debugpy-1.8.0
#   Attempting uninstall: scipy
#     Found existing installation: scipy 1.13.1
#     Uninstalling scipy-1.13.1:
#       Successfully uninstalled scipy-1.13.1
#   Attempting uninstall: pandas
#     Found existing installation: pandas 2.2.2
#     Uninstalling pandas-2.2.2:
#       Successfully uninstalled pandas-2.2.2
#   Attempting uninstall: jupyter_client
#     Found existing installation: jupyter-client 6.1.12
#     Uninstalling jupyter-client-6.1.12:
#       Successfully uninstalled jupyter-client-6.1.12
#   Attempting uninstall: ipython
#     Found existing installation: ipython 7.34.0
#     Uninstalling ipython-7.34.0:
#       Successfully uninstalled ipython-7.34.0
#   Attempting uninstall: ipykernel
#     Found existing installation: ipykernel 6.17.1
#     Uninstalling ipykernel-6.17.1:
#       Successfully uninstalled ipykernel-6.17.1
#   Attempting uninstall: cvxpy
#     Found existing installation: cvxpy 1.6.2
#     Uninstalling cvxpy-1.6.2:
#       Successfully uninstalled cvxpy-1.6.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-colab 1.0.0 requires ipykernel==6.17.1, but you have ipykernel 6.29.5 which is incompatible.
# google-colab 1.0.0 requires ipython==7.34.0, but you have ipython 8.12.3 which is incompatible.
# google-colab 1.0.0 requires pandas==2.2.2, but you have pandas 2.2.3 which is incompatible.
# torch 2.5.1+cu124 requires nvidia-cublas-cu12==12.4.5.8; platform_system == "Linux" and platform_machine == "x86_64", but you have nvidia-cublas-cu12 12.5.3.2 which is incompatible.
# torch 2.5.1+cu124 requires nvidia-cuda-cupti-cu12==12.4.127; platform_system == "Linux" and platform_machine == "x86_64", but you have nvidia-cuda-cupti-cu12 12.5.82 which is incompatible.
# torch 2.5.1+cu124 requires nvidia-cuda-nvrtc-cu12==12.4.127; platform_system == "Linux" and platform_machine == "x86_64", but you have nvidia-cuda-nvrtc-cu12 12.5.82 which is incompatible.
# torch 2.5.1+cu124 requires nvidia-cuda-runtime-cu12==12.4.127; platform_system == "Linux" and platform_machine == "x86_64", but you have nvidia-cuda-runtime-cu12 12.5.82 which is incompatible.
# torch 2.5.1+cu124 requires nvidia-cudnn-cu12==9.1.0.70; platform_system == "Linux" and platform_machine == "x86_64", but you have nvidia-cudnn-cu12 9.3.0.75 which is incompatible.
# torch 2.5.1+cu124 requires nvidia-cufft-cu12==11.2.1.3; platform_system == "Linux" and platform_machine == "x86_64", but you have nvidia-cufft-cu12 11.2.3.61 which is incompatible.
# torch 2.5.1+cu124 requires nvidia-curand-cu12==10.3.5.147; platform_system == "Linux" and platform_machine == "x86_64", but you have nvidia-curand-cu12 10.3.6.82 which is incompatible.
# torch 2.5.1+cu124 requires nvidia-cusolver-cu12==11.6.1.9; platform_system == "Linux" and platform_machine == "x86_64", but you have nvidia-cusolver-cu12 11.6.3.83 which is incompatible.
# torch 2.5.1+cu124 requires nvidia-cusparse-cu12==12.3.1.170; platform_system == "Linux" and platform_machine == "x86_64", but you have nvidia-cusparse-cu12 12.5.1.3 which is incompatible.
# torch 2.5.1+cu124 requires nvidia-nvjitlink-cu12==12.4.127; platform_system == "Linux" and platform_machine == "x86_64", but you have nvidia-nvjitlink-cu12 12.5.82 which is incompatible.
# torch 2.5.1+cu124 requires sympy==1.13.1; python_version >= "3.9", but you have sympy 1.13.3 which is incompatible.
# gensim 4.3.3 requires numpy<2.0,>=1.18.5, but you have numpy 2.1.3 which is incompatible.
# gensim 4.3.3 requires scipy<1.14.0,>=1.7.0, but you have scipy 1.15.2 which is incompatible.
# langchain 0.3.19 requires numpy<2,>=1.26.4; python_version < "3.12", but you have numpy 2.1.3 which is incompatible.
# tensorflow 2.18.0 requires numpy<2.1.0,>=1.26.0, but you have numpy 2.1.3 which is incompatible.
# moviepy 1.0.3 requires decorator<5.0,>=4.0.2, but you have decorator 5.2.1 which is incompatible.
# thinc 8.2.5 requires numpy<2.0.0,>=1.19.0; python_version >= "3.9", but you have numpy 2.1.3 which is incompatible.
# pytensor 2.27.1 requires numpy<2,>=1.17.0, but you have numpy 2.1.3 which is incompatible.
# notebook 6.5.5 requires jupyter-client<8,>=5.3.4, but you have jupyter-client 8.6.3 which is incompatible.
# notebook 6.5.5 requires pyzmq<25,>=17, but you have pyzmq 26.2.1 which is incompatible.
# Successfully installed ImageHash-4.3.1 PyWavelets-1.8.0 Pygments-2.19.1 appnope-0.1.4 asttokens-3.0.0 causalgraphicalmodels-0.0.4 comm-0.2.2 cvxpy-1.6.1 dacite-1.9.2 debugpy-1.8.12 decorator-5.2.1 docopt-0.6.2 executing-2.2.0 htmlmin-0.1.12 ipykernel-6.29.5 ipython-8.12.3 jedi-0.19.2 jupyter_client-8.6.3 multimethod-1.12 numpy-2.1.3 outcome-1.3.0.post0 pandas-2.2.3 pandas-flavor-0.6.0 phik-0.12.4 pipreqs-0.5.0 psutil-7.0.0 pure_eval-0.2.3 python-dateutil-2.9.0.post0 python-dotenv-1.0.1 pyzmq-26.2.1 scipy-1.15.2 selenium-4.29.0 setuptools-75.8.1 stack-data-0.6.3 sympy-1.13.3 traitlets-5.14.3 trio-0.29.0 trio-websocket-0.12.2 visions-0.7.6 webdriver-manager-4.0.2 wsproto-1.2.0 yarg-0.1.9 ydata-profiling-4.12.2

# %% [markdown]
# **Note:** **This notebook demonstrates the application of the DoWhy library for causal analysis. Certain functions are imported as modules. For a detailed examination of these functions, please consult the source code files located in the 'src' directory on GitHub**.

# %% [markdown]
# #Create Causal Graph

# %%
# Create causal Graph
import dowhy
from dowhy import CausalModel
import pandas as pd
import numpy as np
from IPython.display import Image
import pandas as pd
import os
from geopy.distance import geodesic
from sklearn.cluster import KMeans
from sklearn.preprocessing import LabelEncoder
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')
import re
import matplotlib.pyplot as plt
import networkx as nx
from graphviz import Digraph
import pydot
import io
import tempfile
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-bf386705cdef> in <cell line: 0>()
# ----> 1 import dowhy
#       2 from dowhy import CausalModel
#       3 import pandas as pd
#       4 import numpy as np
#       5 from IPython.display import Image
#
# ModuleNotFoundError: No module named 'dowhy'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------
